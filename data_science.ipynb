# %% [markdown]
# # Intro to Data Science with Pokèmon
# ***

# %% [markdown]
# ### Arrays

# %%
food = ["ham", "cheese", "bread", "mayo", "lettuce", "tomato", "bacon"]

# %%
print(food);
# Out:
# ['ham', 'cheese', 'bread', 'mayo', 'lettuce', 'tomato', 'bacon']

# %%
print(food[0])
# Out:
# ham

# %%
sliced_food = food[0:3]

# %%
print(sliced_food)
# Out:
# ['ham', 'cheese', 'bread']

# %% [markdown]
# ### Import Libraries
# ***

# %%
import pandas as pd
import numpy as py
import seaborn as sb

# %%
print("PANDAS Version " + pd.__version__ )
print("numpy version " + py.__version__ )
print("seaborn version " + sb.__version__ )
# Out:
# PANDAS Version 2.1.3
# numpy version 1.26.2
# seaborn version 0.13.0

# %% [markdown]
# ### Loading Data
# ***

# %%
df = pd.read_csv('pokemon.csv')

# %%
df.head()
# Out:
#    Per  Nat     Pokemon  HP  Atk  Def  SpA  SpD  Spe  Total  ... Catch  \
# 0  1.0  1.0   Bulbasaur  45   49   49   65   65   45    318  ...    45
# 1  2.0  2.0     Ivysaur  60   62   63   80   80   60    405  ...    45
# 2  3.0  3.0    Venusaur  80   82   83  100  100   80    525  ...    45
# 3  4.0  4.0  Charmander  39   52   43   60   50   65    309  ...    45
# 4  5.0  5.0  Charmeleon  58   64   58   80   65   80    405  ...    45
#
#        EXP  Evolve Per.1 Nat.1    Joh Hoe  Sin  Un   Pokemon.1
# 0  1059860     NaN   1.0   1.0  226.0 NaN  NaN NaN   Bulbasaur
# 1  1059860  Lv. 16   2.0   2.0  227.0 NaN  NaN NaN     Ivysaur
# 2  1059860  Lv. 32   3.0   3.0  228.0 NaN  NaN NaN    Venusaur
# 3  1059860     NaN   4.0   4.0  229.0 NaN  NaN NaN  Charmander
# 4  1059860  Lv. 16   5.0   5.0  230.0 NaN  NaN NaN  Charmeleon
#
# [5 rows x 35 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
df.head(80)
# Out:
#      Per   Nat     Pokemon  HP  Atk  Def  SpA  SpD  Spe  Total  ... Catch  \
# 0    1.0   1.0   Bulbasaur  45   49   49   65   65   45    318  ...    45
# 1    2.0   2.0     Ivysaur  60   62   63   80   80   60    405  ...    45
# 2    3.0   3.0    Venusaur  80   82   83  100  100   80    525  ...    45
# 3    4.0   4.0  Charmander  39   52   43   60   50   65    309  ...    45
# 4    5.0   5.0  Charmeleon  58   64   58   80   65   80    405  ...    45
# ..   ...   ...         ...  ..  ...  ...  ...  ...  ...    ...  ...   ...
# 75  82.0  76.0       Golem  80  110  130   55   65   45    485  ...    45
# 76  83.0  77.0      Ponyta  50   85   55   65   65   90    410  ...   190
# 77  84.0  78.0    Rapidash  65  100   70   80   80  105    500  ...    60
# 78  85.0  79.0    Slowpoke  90   65   65   40   40   15    315  ...   190
# 79  86.0  80.0     Slowbro  95   75  110  100   80   30    490  ...    75
#
#         EXP  Evolve Per.1 Nat.1    Joh   Hoe   Sin  Un   Pokemon.1
# 0   1059860     NaN   1.0   1.0  226.0   NaN   NaN NaN   Bulbasaur
# 1   1059860  Lv. 16   2.0   2.0  227.0   NaN   NaN NaN     Ivysaur
# 2   1059860  Lv. 32   3.0   3.0  228.0   NaN   NaN NaN    Venusaur
# 3   1059860     NaN   4.0   4.0  229.0   NaN   NaN NaN  Charmander
# 4   1059860  Lv. 16   5.0   5.0  230.0   NaN   NaN NaN  Charmeleon
# ..      ...     ...   ...   ...    ...   ...   ...  ..         ...
# 75  1059860   Trade  82.0  76.0   36.0  59.0  33.0 NaN       Golem
# 76  1000000     NaN  83.0  77.0  201.0   NaN  77.0 NaN      Ponyta
# 77  1000000  Lv. 40  84.0  78.0  202.0   NaN  78.0 NaN    Rapidash
# 78  1000000     NaN  85.0  79.0   80.0   NaN   NaN NaN    Slowpoke
# 79  1000000  Lv. 37  86.0  80.0   81.0   NaN   NaN NaN     Slowbro
#
# [80 rows x 35 columns]
